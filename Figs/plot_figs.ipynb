# %%
import matplotlib
import matplotlib.pylab as plt
ax=plt.gca()

index=1
# total 149 colors, arranged in 15x10
for name, hex in matplotlib.colors.cnames.items():
    x=index/15
    y=index%15
    print(name,hex,x,y)
    circle=plt.Circle((x,y),radius=0.3,color=hex)
    ax.add_artist(circle)
    index+=1
print index    
ax.set_xlim([-1,10])
ax.set_ylim([-1,15])    
plt.show()
# Out:
# (u'indigo', u'#4B0082', 0, 1)
# (u'gold', u'#FFD700', 0, 2)
# (u'hotpink', u'#FF69B4', 0, 3)
# (u'firebrick', u'#B22222', 0, 4)
# (u'indianred', u'#CD5C5C', 0, 5)
# (u'yellow', u'#FFFF00', 0, 6)
# (u'mistyrose', u'#FFE4E1', 0, 7)
# (u'darkolivegreen', u'#556B2F', 0, 8)
# (u'olive', u'#808000', 0, 9)
# (u'darkseagreen', u'#8FBC8F', 0, 10)
# (u'pink', u'#FFC0CB', 0, 11)
# (u'tomato', u'#FF6347', 0, 12)
# (u'lightcoral', u'#F08080', 0, 13)
# (u'orangered', u'#FF4500', 0, 14)
# (u'navajowhite', u'#FFDEAD', 1, 0)
# (u'lime', u'#00FF00', 1, 1)
# (u'palegreen', u'#98FB98', 1, 2)
# (u'darkslategrey', u'#2F4F4F', 1, 3)
# (u'greenyellow', u'#ADFF2F', 1, 4)
# (u'burlywood', u'#DEB887', 1, 5)
# (u'seashell', u'#FFF5EE', 1, 6)
# (u'mediumspringgreen', u'#00FA9A', 1, 7)
# (u'fuchsia', u'#FF00FF', 1, 8)
# (u'papayawhip', u'#FFEFD5', 1, 9)
# (u'blanchedalmond', u'#FFEBCD', 1, 10)
# (u'chartreuse', u'#7FFF00', 1, 11)
# (u'dimgray', u'#696969', 1, 12)
# (u'black', u'#000000', 1, 13)
# ...

# %%
cd /Users/ximing/Documents/dissertation/paper_pictures/Figs
# Out:
# /Users/ximing/Documents/dissertation/paper_pictures/Figs

# %%
from math import *
import numpy as np
#import matplotlib.pylab as plt
import activated_count
ac=reload(activated_count)

# %%
cd ../camkii_sims
# Out:
# /Users/ximing/Documents/dissertation/paper_pictures/camkii_sims

# %%
ca_tot5hz=41533.0
ca_tot10hz=48433.0
ca_tot5hz_8ch=23672.0
ca_tot10hz_8ch=18272.0
ca_tot10hz_scaled=40840.0
ca_tot5hz_8ch_scaled=17688

# %%
bK10_6_nd00s2_8ch=np.transpose(np.loadtxt('10hz_6subunits_nd00xconc_8ch_s2/molcount_bK_10hz.txt'))
bK10_3_nd00s2_8ch=np.transpose(np.loadtxt('10hz_3subunits_nd00xconc_8ch_s2/molcount_bK_10hz.txt'))
bK5_6_nd00s2_8ch=np.transpose(np.loadtxt('5hz_6subunits_nd00xconc_8ch_s2/molcount_bK_5hz.txt'))
bK5_3_nd00s2_8ch=np.transpose(np.loadtxt('5hz_3subunits_nd00xconc_8ch_s2/molcount_bK_5hz.txt'))

# %%
cam10_6_nd00s2_8ch=np.transpose(np.loadtxt('10hz_6subunits_nd00xconc_8ch_s2/molcount_cam_10hz.txt'))
cam10_3_nd00s2_8ch=np.transpose(np.loadtxt('10hz_3subunits_nd00xconc_8ch_s2/molcount_cam_10hz.txt'))
cam5_6_nd00s2_8ch=np.transpose(np.loadtxt('5hz_6subunits_nd00xconc_8ch_s2/molcount_cam_5hz.txt'))
cam5_3_nd00s2_8ch=np.transpose(np.loadtxt('5hz_3subunits_nd00xconc_8ch_s2/molcount_cam_5hz.txt'))

# %%
# not sure if the smaller total ca is causes the deviation in frequency
# have to compare 10hz_8ch vs 5hz_8ch
# effect of 10hz vs 5hz given 8ch, nd00xconc and s2
plt.plot(bK10_6_nd00s2_8ch[0],ac.camkii_count(bK10_6_nd00s2_8ch,'p')/ca_tot10hz_8ch,'b--')
plt.plot(bK10_3_nd00s2_8ch[0],ac.camkii_count(bK10_3_nd00s2_8ch,'p')/ca_tot10hz_8ch,'g--')
plt.plot(bK5_6_nd00s2_8ch[0],ac.camkii_count(bK5_6_nd00s2_8ch,'p')/ca_tot5hz_8ch,'b')
plt.plot(bK5_3_nd00s2_8ch[0],ac.camkii_count(bK5_3_nd00s2_8ch,'p')/ca_tot5hz_8ch,'g')
plt.show()

# %%
plt.plot(cam10_6_nd00s2_8ch[0],(ac.cam_count(cam10_6_nd00s2_8ch,'camK')+cam10_6_nd00s2_8ch[17])/ca_tot10hz_8ch,'k--')
plt.plot(cam10_6_nd00s2_8ch[0],(ac.cam_count(cam10_6_nd00s2_8ch,'camKp')+cam10_6_nd00s2_8ch[49])/ca_tot10hz_8ch,'k')
plt.plot(cam5_6_nd00s2_8ch[0],(ac.cam_count(cam5_6_nd00s2_8ch,'camK')+cam5_6_nd00s2_8ch[17])/ca_tot5hz_8ch,'r--')
plt.plot(cam5_6_nd00s2_8ch[0],(ac.cam_count(cam5_6_nd00s2_8ch,'camKp')+cam5_6_nd00s2_8ch[49])/ca_tot5hz_8ch,'r')
plt.show()

# %%
plt.plot(cam10_3_nd00s2_8ch[0],(ac.cam_count(cam10_3_nd00s2_8ch,'camK')+cam10_3_nd00s2_8ch[17])/ca_tot10hz_8ch,'k--')
plt.plot(cam10_3_nd00s2_8ch[0],(ac.cam_count(cam10_3_nd00s2_8ch,'camKp')+cam10_3_nd00s2_8ch[49])/ca_tot10hz_8ch,'k')
plt.plot(cam5_3_nd00s2_8ch[0],(ac.cam_count(cam5_3_nd00s2_8ch,'camK')+cam5_3_nd00s2_8ch[17])/ca_tot5hz_8ch,'r--')
plt.plot(cam5_3_nd00s2_8ch[0],(ac.cam_count(cam5_3_nd00s2_8ch,'camKp')+cam5_3_nd00s2_8ch[49])/ca_tot5hz_8ch,'r')
plt.show()

# %%
bK10_6=np.transpose(np.loadtxt('10hz_6subunits/molcount_bK_10hz.txt'))
bK10_3=np.transpose(np.loadtxt('10hz_3subunits/molcount_bK_10hz.txt'))
bK5_6=np.transpose(np.loadtxt('5hz_6subunits/molcount_bK_5hz.txt'))
bK5_3=np.transpose(np.loadtxt('5hz_3subunits/molcount_bK_5hz.txt'))

# %%
cam10_6=np.transpose(np.loadtxt('10hz_6subunits/molcount_cam_10hz.txt'))
cam10_3=np.transpose(np.loadtxt('10hz_3subunits/molcount_cam_10hz.txt'))
cam5_6=np.transpose(np.loadtxt('5hz_6subunits/molcount_cam_5hz.txt'))
cam5_3=np.transpose(np.loadtxt('5hz_3subunits/molcount_cam_5hz.txt'))

# %%
# effect of 10hz vs 5hz given normal diffsuion, nanodomain
plt.plot(bK10_6[0],ac.camkii_count(bK10_6,'p')/ca_tot10hz,'b--')
plt.plot(bK10_3[0],ac.camkii_count(bK10_3,'p')/ca_tot10hz,'g--')
plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'p')/ca_tot5hz,'b')
plt.plot(bK5_3[0],ac.camkii_count(bK5_3,'p')/ca_tot5hz,'g')
plt.show()

# %%
bK5_6_nd00=np.transpose(np.loadtxt('5hz_6subunits_nd00xconc/molcount_bK_5hz.txt'))
bK5_3_nd00=np.transpose(np.loadtxt('5hz_3subunits_nd00xconc/molcount_bK_5hz.txt'))
cam5_6_nd00=np.transpose(np.loadtxt('5hz_6subunits_nd00xconc/molcount_cam_5hz.txt'))
cam5_3_nd00=np.transpose(np.loadtxt('5hz_3subunits_nd00xconc/molcount_cam_5hz.txt'))

# %%
# effect of nd00xconc, given 5hz, normal diffusion and the same total ca influx
# 3sub > 6sub
plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'p')/ca_tot5hz,'b')
plt.plot(bK5_3[0],ac.camkii_count(bK5_3,'p')/ca_tot5hz,'g')
plt.plot(bK5_6_nd00[0],ac.camkii_count(bK5_6_nd00,'p')/ca_tot5hz,'r')
plt.plot(bK5_3_nd00[0],ac.camkii_count(bK5_3_nd00,'p')/ca_tot5hz,'k')
plt.show()

# %%
bK5_6_nd00_8ch=np.transpose(np.loadtxt('5hz_6subunits_nd00xconc_8ch/molcount_bK_5hz.txt'))
bK5_3_nd00_8ch=np.transpose(np.loadtxt('5hz_3subunits_nd00xconc_8ch/molcount_bK_5hz.txt'))
cam5_6_nd00_8ch=np.transpose(np.loadtxt('5hz_6subunits_nd00xconc_8ch/molcount_cam_5hz.txt'))
cam5_3_nd00_8ch=np.transpose(np.loadtxt('5hz_3subunits_nd00xconc_8ch/molcount_cam_5hz.txt'))

# %%
# effect of 8ch, given nd00xconc, 5hz and normal diffusion
# nd00: 3sub > 6sub; nd00 + 8ch: 6sub > 3sub
plt.plot(bK5_6_nd00[0],ac.camkii_count(bK5_6_nd00,'p'),'b')
plt.plot(bK5_3_nd00[0],ac.camkii_count(bK5_3_nd00,'p'),'g')
plt.plot(bK5_6_nd00_8ch[0],ac.camkii_count(bK5_6_nd00_8ch,'p'),'r')
plt.plot(bK5_3_nd00_8ch[0],ac.camkii_count(bK5_3_nd00_8ch,'p'),'k')
plt.show()

# %%
# effect of s2, given nd00xconc, 5hz and 8ch
plt.plot(bK5_6_nd00_8ch[0],ac.camkii_count(bK5_6_nd00_8ch,'p'),'b')
plt.plot(bK5_3_nd00_8ch[0],ac.camkii_count(bK5_3_nd00_8ch,'p'),'g')
plt.plot(bK5_6_nd00s2_8ch[0],ac.camkii_count(bK5_6_nd00s2_8ch,'p'),'r')
plt.plot(bK5_3_nd00s2_8ch[0],ac.camkii_count(bK5_3_nd00s2_8ch,'p'),'k')
plt.show()

# %%
# effect of s2
#plt.plot(bK5_6_nd00[0],ac.camkii_count(bK5_6_nd00_8ch,'p')/ca_tot5hz_8ch,'b')
#plt.plot(bK5_3_nd00[0],ac.camkii_count(bK5_3_nd00_8ch,'p')/ca_tot5hz_8ch,'g')
#plt.plot(bK5_6_nd00s2[0],ac.camkii_count(bK5_6_nd00s2_8ch,'p')/ca_tot5hz_8ch,'r')
#plt.plot(bK5_3_nd00s2[0],ac.camkii_count(bK5_3_nd00s2_8ch,'p')/ca_tot5hz_8ch,'k')

# %%
bK5_6_s2=np.transpose(np.loadtxt('5hz_6subunits_diff_s2/molcount_bK_5hz.txt'))
bK5_3_s2=np.transpose(np.loadtxt('5hz_3subunits_diff_s2/molcount_bK_5hz.txt'))
cam5_6_s2=np.transpose(np.loadtxt('5hz_6subunits_diff_s2/molcount_cam_5hz.txt'))
cam5_3_s2=np.transpose(np.loadtxt('5hz_3subunits_diff_s2/molcount_cam_5hz.txt'))

# %%
# effect of s2, given 5hz, normal diffusion, normal total ca2+ influx
plt.plot(bK5_6_s2[0],ac.camkii_count(bK5_6_s2,'p')/ca_tot5hz,'b')
plt.plot(bK5_3_s2[0],ac.camkii_count(bK5_3_s2,'p')/ca_tot5hz,'g')
plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'p')/ca_tot5hz,'r')
plt.plot(bK5_3[0],ac.camkii_count(bK5_3,'p')/ca_tot5hz,'k')
plt.show()

# %%
plt.plot(cam5_6[0],ac.cam_count(cam5_6,'cam'),'k',lw=0.8)
plt.plot(cam5_6[0],ac.cam_count(cam5_6,'camK'),'c',lw=0.8)
plt.plot(cam5_6[0],ac.cam_count(cam5_6,'camKp')+cam5_6[49],'lime',lw=0.8)

plt.plot(cam5_6_s2[0],ac.cam_count(cam5_6_s2,'cam'),'crimson',lw=0.8)
plt.plot(cam5_6_s2[0],ac.cam_count(cam5_6_s2,'camK'),'gold',lw=0.8)
plt.plot(cam5_6_s2[0],ac.cam_count(cam5_6_s2,'camKp')+cam5_6_s2[49],'orangered',lw=0.8)

'''
plt.plot(cam5_3[0],ac.cam_count(cam5_3,'cam'),'k',linestyle='--')
plt.plot(cam5_3[0],ac.cam_count(cam5_3,'camK'),'c',linestyle='--')
plt.plot(cam5_3_s2[0],ac.cam_count(cam5_3_s2,'cam'),'crimson',linestyle='--')
plt.plot(cam5_3_s2[0],ac.cam_count(cam5_3_s2,'camK'),'gold',linestyle='--')
'''
plt.show()

# %%
#plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'p')-ac.camkii_count(bK5_6,'n2'),'firebrick')
#plt.plot(bK5_3[0],ac.camkii_count(bK5_3,'p')-ac.camkii_count(bK5_3,'n2'),'steelblue')

#plt.plot(bK5_6_s2[0],ac.camkii_count(bK5_6_s2,'p')-ac.camkii_count(bK5_6_s2,'n2'),'firebrick')
#plt.plot(bK5_3_s2[0],ac.camkii_count(bK5_3_s2,'p')-ac.camkii_count(bK5_3_s2,'n2'),'steelblue')
plt.subplot(311)
plt.plot(bK5_6_s2[0],(ac.camkii_count(bK5_6_s2,'p')-ac.camkii_count(bK5_3_s2,'p'))/ca_tot5hz,'firebrick')
plt.plot(bK5_3_s2[0],(ac.camkii_count(bK5_6_s2,'n2')-ac.camkii_count(bK5_3_s2,'n2'))/ca_tot5hz,'steelblue',lw=0.5)
plt.plot(bK5_3_s2[0],(ac.camkii_count(bK5_6_s2,'b')-ac.camkii_count(bK5_3_s2,'b'))/ca_tot5hz,'c',lw=0.5)

plt.subplot(312)
plt.plot(bK5_6[0],(ac.camkii_count(bK5_6,'p')-ac.camkii_count(bK5_3,'p'))/ca_tot5hz,'firebrick')
plt.plot(bK5_3[0],(ac.camkii_count(bK5_6,'n2')-ac.camkii_count(bK5_3,'n2'))/ca_tot5hz,'steelblue',lw=0.5)
plt.plot(bK5_3[0],(ac.camkii_count(bK5_6,'b')-ac.camkii_count(bK5_3,'b'))/ca_tot5hz,'c',lw=0.5)

plt.subplot(313)
plt.plot(bK5_6_nd00_8ch[0],(ac.camkii_count(bK5_6_nd00_8ch,'p')-ac.camkii_count(bK5_3_nd00_8ch,'p'))/ca_tot5hz_8ch,'firebrick')
plt.plot(bK5_3_nd00_8ch[0],(ac.camkii_count(bK5_6_nd00_8ch,'n2')-ac.camkii_count(bK5_3_nd00_8ch,'n2'))/ca_tot5hz_8ch,'steelblue',lw=0.5)
plt.plot(bK5_3_nd00_8ch[0],(ac.camkii_count(bK5_6_nd00_8ch,'b')-ac.camkii_count(bK5_3_nd00_8ch,'b'))/ca_tot5hz_8ch,'c',lw=0.5)

#plt.plot(bK5_6_s2[0],ac.camkii_count(bK5_6_s2,'n2'),'firebrick')
#plt.plot(bK5_3_s2[0],ac.camkii_count(bK5_3_s2,'n2'),'steelblue')

#plt.plot(bK5_6_nd00_8ch[0],ac.camkii_count(bK5_6_nd00_8ch,'n2'),'firebrick')
#plt.plot(bK5_3_nd00_8ch[0],ac.camkii_count(bK5_3_nd00_8ch,'n2'),'steelblue')

plt.show()

# %%
plt.plot(bK10_6_nd00s2_8ch[0],(ac.camkii_count(bK10_6_nd00s2_8ch,'p')-ac.camkii_count(bK10_3_nd00s2_8ch,'p'))/ca_tot10hz_8ch,'firebrick')
plt.plot(bK10_6_nd00s2_8ch[0],(ac.camkii_count(bK10_6_nd00s2_8ch,'n2')-ac.camkii_count(bK10_3_nd00s2_8ch,'n2'))/ca_tot10hz_8ch,'steelblue',lw=0.5)
plt.plot(bK10_6_nd00s2_8ch[0],(ac.camkii_count(bK10_6_nd00s2_8ch,'b')-ac.camkii_count(bK10_3_nd00s2_8ch,'b'))/ca_tot10hz_8ch,'c',lw=0.5)
plt.show()

# %%
bK5_6_8ch=np.transpose(np.loadtxt('5hz_6subunits_8ch/molcount_bK_5hz.txt'))
bK5_3_8ch=np.transpose(np.loadtxt('5hz_3subunits_8ch/molcount_bK_5hz.txt'))

# %%
plt.plot(bK5_6_8ch[0],ac.camkii_count(bK5_6_8ch,'p'),'b')
plt.plot(bK5_3_8ch[0],ac.camkii_count(bK5_3_8ch,'p'),'g')
plt.plot(bK5_6_nd00_8ch[0],ac.camkii_count(bK5_6_nd00_8ch,'p'),'r')
plt.plot(bK5_3_nd00_8ch[0],ac.camkii_count(bK5_3_nd00_8ch,'p'),'k')
#plt.plot(bK5_6_nd00s2_8ch[0],ac.camkii_count(bK5_6_nd00s2_8ch,'p'),'gold')
#plt.plot(bK5_3_nd00s2_8ch[0],ac.camkii_count(bK5_3_nd00s2_8ch,'p'),'steelblue')
plt.show()

# %%
plt.plot(bK5_6_8ch[0],ac.camkii_count(bK5_6_8ch,'p')-ac.camkii_count(bK5_3_8ch,'p'),'firebrick')
plt.plot(bK5_6_8ch[0],ac.camkii_count(bK5_6_8ch,'n2')-ac.camkii_count(bK5_3_8ch,'n2'),'steelblue',lw=0.5)
#plt.plot(bK5_6_8ch[0],ac.camkii_count(bK5_6_8ch,'b')-ac.camkii_count(bK5_3_8ch,'b'),'c',lw=0.5)
plt.show()

# %%
bK025_6=np.transpose(np.loadtxt('../ca_conserve/ca025cam_6subunits/molcount_bK.txt'))
bK025_3=np.transpose(np.loadtxt('../ca_conserve/ca025cam_3subunits/molcount_bK.txt'))
cam025_6=np.transpose(np.loadtxt('../ca_conserve/ca025cam_6subunits/molcount_cam.txt'))
cam025_3=np.transpose(np.loadtxt('../ca_conserve/ca025cam_3subunits/molcount_cam.txt'))

# %%
plt.plot(bK025_6[0],ac.camkii_count(bK025_6,'p'),'gold')
plt.plot(bK025_6[0],ac.camkii_count(bK025_6,'n2'),'gold',linestyle='-.')


plt.plot(bK025_3[0],ac.camkii_count(bK025_3,'p'),'steelblue')
plt.plot(bK025_3[0],ac.camkii_count(bK025_3,'n2'),'steelblue',linestyle='-.')


plt.show()

# %%
#plt.plot(cam025_6[0],ac.cam_count(cam025_6,'camK'),'darkgreen')
plt.plot(cam025_6[0],ac.cam_count(cam025_6,'camKp'),'darkgreen')
plt.plot(cam025_6[0],cam025_6[49],'yellowgreen')

#plt.plot(cam025_3[0],ac.cam_count(cam025_3,'camK'),'limegreen')
plt.plot(cam025_3[0],ac.cam_count(cam025_3,'camKp'),'limegreen')
plt.plot(cam025_3[0],cam025_3[49],'red')

#ac.cam_graph(cam025_6,cam025_3,'ca')

plt.show()

# %%
cam01_6=np.transpose(np.loadtxt('../ca_conserve/ca01cam_6subunits/molcount_cam.txt'))
cam01_3=np.transpose(np.loadtxt('../ca_conserve/ca01cam_3subunits/molcount_cam.txt'))

# %%
plt.plot(cam01_6[0],ac.cam_count(cam01_6,'camKp'),'darkgreen')
plt.plot(cam01_6[0],cam01_6[49],'yellowgreen')

plt.plot(cam01_3[0],ac.cam_count(cam01_3,'camKp'),'limegreen')
plt.plot(cam01_3[0],cam01_3[49],'red')

plt.show()

# %%
cam05_6=np.transpose(np.loadtxt('../ca_conserve/ca05cam_6subunits/molcount_cam.txt'))
cam05_3=np.transpose(np.loadtxt('../ca_conserve/ca05cam_3subunits/molcount_cam.txt'))

# %%
plt.plot(cam05_6[0],ac.cam_count(cam05_6,'camKp'),'darkgreen')
plt.plot(cam05_6[0],cam05_6[49],'yellowgreen')

plt.plot(cam05_3[0],ac.cam_count(cam05_3,'camKp'),'limegreen')
plt.plot(cam05_3[0],cam05_3[49],'red')

plt.show()

# %%
bK10_6_scaled=np.transpose(np.loadtxt('../scaled/10hz_6subunits_scaled/molcount_bK_10hz.txt'))
bK10_3_scaled=np.transpose(np.loadtxt('../scaled/10hz_3subunits_scaled/molcount_bK_10hz.txt'))
cam10_6_scaled=np.transpose(np.loadtxt('../scaled/10hz_6subunits_scaled/molcount_cam_10hz.txt'))
cam10_3_scaled=np.transpose(np.loadtxt('../scaled/10hz_3subunits_scaled/molcount_cam_10hz.txt'))

# %%
plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'p'))
plt.plot(bK10_3_scaled[0],ac.camkii_count(bK10_3_scaled,'p'),linestyle='--')

plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'p'))
plt.plot(bK5_3[0],ac.camkii_count(bK5_3,'p'),linestyle='--')
plt.show()

# %%
bK10_6_8ch=np.transpose(np.loadtxt('10hz_6subunits_8ch/molcount_bK_10hz.txt'))
bK10_3_8ch=np.transpose(np.loadtxt('10hz_3subunits_8ch/molcount_bK_10hz.txt'))
bK5_6_8ch_scaled=np.transpose(np.loadtxt('../scaled/5hz_6subunits_8ch_scaled/molcount_bK_5hz.txt'))
bK5_3_8ch_scaled=np.transpose(np.loadtxt('../scaled/5hz_3subunits_8ch_scaled/molcount_bK_5hz.txt'))
bK10_6_s2=np.transpose(np.loadtxt('10hz_6subunits_diff_s2/molcount_bK_10hz.txt'))
cam10_6_s2=np.transpose(np.loadtxt('10hz_6subunits_diff_s2/molcount_cam_10hz.txt'))
cam10_6_8ch=np.transpose(np.loadtxt('10hz_6subunits_8ch/molcount_cam_10hz.txt'))
cam5_6_8ch_scaled=np.transpose(np.loadtxt('../scaled/5hz_6subunits_8ch_scaled/molcount_cam_5hz.txt'))

# %%
#plt.plot(bK10_6_8ch[0],ac.camkii_count(bK10_6_8ch,'p'))
#plt.plot(bK10_3_8ch[0],ac.camkii_count(bK10_3_8ch,'p'),linestyle='--')
#plt.plot(bK5_6_8ch_scaled[0],ac.camkii_count(bK5_6_8ch_scaled,'p'))
#plt.plot(bK5_3_8ch_scaled[0],ac.camkii_count(bK5_3_8ch_scaled,'p'),linestyle='--')
#plt.show()
print ac.camkii_count(bK10_6_8ch,'p')[-1]/ac.camkii_count(bK5_6_8ch_scaled,'p')[-1]
print ac.camkii_count(bK10_3_8ch,'p')[-1]/ac.camkii_count(bK5_3_8ch_scaled,'p')[-1]
print ac.camkii_count(bK10_6_scaled,'p')[-1]/ac.camkii_count(bK5_6,'p')[-1]
print ac.camkii_count(bK10_3_scaled,'p')[-1]/ac.camkii_count(bK5_3,'p')[-1]
# Out:
# 2.0625
# 2.11111111111
# 1.74907749077
# 1.29663608563

# %%
plt.plot(bK5_6_8ch_scaled[0],ac.camkii_count(bK5_6_8ch_scaled,'p'))
plt.plot(bK5_3_8ch_scaled[0],ac.camkii_count(bK5_3_8ch_scaled,'p'),linestyle='--')
plt.plot(bK5_6_8ch[0],ac.camkii_count(bK5_6_8ch,'p'))
plt.plot(bK5_3_8ch[0],ac.camkii_count(bK5_3_8ch,'p'),linestyle='--')

plt.show()

# %%
plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'p'),'k')
plt.plot(cam10_6_scaled[0],ac.cam_count(cam10_6_scaled,'camKp')+cam10_6_scaled[49],'r')
plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'p')-ac.camkii_count(bK10_6_scaled,'bp'),'b--')
plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'n2'),'gold')
plt.plot(bK10_3_scaled[0],ac.camkii_count(bK10_3_scaled,'n2'),'orange')

#plt.plot(cam10_6_scaled[0],ac.cam_count(cam10_6_scaled,'camK')+cam10_6_scaled[17],'brown')
# overlap with the brown line
#plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'b')-ac.camkii_count(bK10_6_scaled,'bp'),'g--',lw=2) 
plt.plot(cam10_6_scaled[0],cam10_6_scaled[12+1+48]+cam10_6_scaled[13+1+48]+cam10_6_scaled[15+1+48],'aqua')
plt.plot(cam10_6_scaled[0],cam10_6_scaled[12+1+16]+cam10_6_scaled[13+1+16]+cam10_6_scaled[15+1+16],'lime')
plt.plot(cam10_6[0],(cam10_6[12+1+16]+cam10_6[13+1+16]+cam10_6[15+1+16]),'darkgreen')
plt.plot(cam10_6[0],cam10_6[12+1+48]+cam10_6[13+1+48]+cam10_6[15+1+48],'purple')

plt.show()

# %%
cam_species=["N1C0","N2C0","N0C1","N1C1","N2C1","N0C2","N1C2","N2C2"]
colorlist=['tomato','yellowgreen','gold','darkblue','black','dodgerblue','chocolate','teal']
index=[1+1,3+1,4+1,5+1,7+1,12+1,13+1,15+1]
indexK=[1+1+16,3+1+16,4+1+16,5+1+16,7+1+16,12+1+16,13+1+16,15+1+16]
indexKp=[1+1+48,3+1+48,4+1+48,5+1+48,7+1+48,12+1+48,13+1+48,15+1+48]
index_tmp=index
cam1=cam10_6_scaled
cam2=cam5_6

width=0.4
D10_6_scaled_sum =dict()
#D5_6_nd00_sum=dict()
D=D10_6_scaled_sum
for i in range(0,len(cam_species)):
    D[cam_species[i]]=np.sum(cam1[index_tmp[i]],0)
barlist=plt.bar(np.arange(len(D))+width/2, D.values(),width)
for i in range(0,len(D.keys())):
    indx=cam_species.index(D.keys()[i])
    barlist[i].set_color(colorlist[indx])
plt.xticks(range(len(D)), D.keys())

D5_6_sum =dict()
D=D5_6_sum
for i in range(0,len(cam_species)):
    D[cam_species[i]]=np.sum(cam2[index_tmp[i]],0)
barlist=plt.bar(np.arange(len(D)), D.values(), width,hatch='//')
for i in range(0,len(D.keys())):
    indx=cam_species.index(D.keys()[i])
    barlist[i].set_color(colorlist[indx])
plt.xticks(range(len(D)), D.keys())
plt.show()

# %%
plt_list=['N0C1','N0C2','N1C0','N2C0']

ax1=plt.subplot(121)
for i_name in plt_list:
    i=cam_species.index(i_name)
    ax1.plot(cam1[0],cam1[index_tmp[i]],colorlist[i],lw=0.7)
#ax1.set_ylim([0,1000])
#ax1.set_xlim([0,1200])

ax2=plt.subplot(122)
for i_name in plt_list:
    i=cam_species.index(i_name)
    ax2.plot(cam2[0],cam2[index_tmp[i]],colorlist[i],lw=0.7)
#ax2.set_ylim([0,1000])
#ax2.set_xlim([0,1200])

plt.show()

# %%
plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'p'),'k')
plt.plot(cam10_6_scaled[0],ac.cam_count(cam10_6_scaled,'camKp')+cam10_6_scaled[49],'r')
plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'p')-ac.camkii_count(bK10_6_scaled,'bp'),'b--')
plt.plot(bK10_6_scaled[0],ac.camkii_count(bK10_6_scaled,'n2'),'gold')

plt.plot(cam10_6_scaled[0],cam10_6_scaled[12+1+48]+cam10_6_scaled[13+1+48]+cam10_6_scaled[15+1+48],'aqua')
plt.plot(cam10_6_scaled[0],cam10_6_scaled[12+1+16]+cam10_6_scaled[13+1+16]+cam10_6_scaled[15+1+16],'lime')

plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'p'),'k')
plt.plot(cam5_6[0],ac.cam_count(cam5_6,'camKp')+cam5_6[49],'r')
plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'p')-ac.camkii_count(bK5_6,'bp'),'b--')
plt.plot(bK5_6[0],ac.camkii_count(bK5_6,'n2'),'gold')

plt.plot(cam5_6[0],cam5_6[12+1+48]+cam5_6[13+1+48]+cam5_6[15+1+48],'aqua')
plt.plot(cam5_6[0],cam5_6[12+1+16]+cam5_6[13+1+16]+cam5_6[15+1+16],'lime')
print "cam10_6_scaled: N0C2%=",np.sum(cam10_6_scaled[12+1+16],0)/np.sum(cam10_6_scaled[12+1+16]+cam10_6_scaled[13+1+16]+cam10_6_scaled[15+1+16],0)
print "cam10_6_scaled: N2C2%=",np.sum(cam10_6_scaled[15+1+16],0)/np.sum(cam10_6_scaled[12+1+16]+cam10_6_scaled[13+1+16]+cam10_6_scaled[15+1+16],0)
print "cam5_6: N0C2%=",np.sum(cam5_6[12+1+16],0)/np.sum(cam5_6[12+1+16]+cam5_6[13+1+16]+cam5_6[15+1+16],0)
print "cam5_6: N2C2%=",np.sum(cam5_6[15+1+16],0)/np.sum(cam5_6[12+1+16]+cam5_6[13+1+16]+cam5_6[15+1+16],0)

plt.show()
# Out:
# cam10_6_scaled: N0C2%= 0.698000592266
# cam10_6_scaled: N2C2%= 0.184438726016
# cam5_6: N0C2%= 0.768761132103
# cam5_6: N2C2%= 0.124225514522

# %%
#for i in range(0,16):
#   plt.plot(cam10_6_scaled[0],cam10_6_scaled[1+i+48],lw=0.5)
fig=plt.figure()
ax1=fig.add_subplot(121)
ax1.plot(cam10_6_scaled[0],cam10_6_scaled[1+12+16],lw=0.5)
#ax1.plot(cam10_6_scaled[0],cam10_6_scaled[1+13+16],lw=0.5)
#ax1.plot(cam10_6_scaled[0],cam10_6_scaled[1+15+16],lw=0.5)
ax1.plot(cam10_6_scaled[0],cam10_6_scaled[1+12+48],lw=0.5)
ax1.plot(cam10_6_scaled[0],cam10_6_scaled[1+13+48],lw=0.5)
ax1.plot(cam10_6_scaled[0],cam10_6_scaled[1+15+48],lw=0.5)
ax1.set_ylim([0,1250])
ax1.set_xlim([0,1800])

ax2=fig.add_subplot(122)
ax2.plot(cam5_6[0],cam5_6[1+12+16],lw=0.5)
ax2.plot(cam5_6[0],cam5_6[1+13+16],lw=0.5)
ax2.plot(cam5_6[0],cam5_6[1+15+16],lw=0.5)
ax2.plot(cam5_6[0],cam5_6[1+12+48],lw=0.5)
ax2.plot(cam5_6[0],cam5_6[1+13+48],lw=0.5)
ax2.plot(cam5_6[0],cam5_6[1+15+48],lw=0.5)
ax2.set_ylim([0,1250])
ax2.set_xlim([0,1800])
plt.show()

# %%
bK10_6_lk=np.transpose(np.loadtxt('../cam_leak/10hz_6subunits/molcount_bK_10hz.txt'))
cam10_6_lk=np.transpose(np.loadtxt('../cam_leak/10hz_6subunits/molcount_cam_10hz.txt'))
bK5_6_lk=np.transpose(np.loadtxt('../cam_leak/5hz_6subunits/molcount_bK_5hz.txt'))
cam5_6_lk=np.transpose(np.loadtxt('../cam_leak/5hz_6subunits/molcount_cam_5hz.txt'))

# %%
#for i in range(0,16):
#   plt.plot(cam10_6_scaled[0],cam10_6_scaled[1+i+48],lw=0.5)
fig=plt.figure()
ax1=fig.add_subplot(121)
ax1.plot(cam10_6_s2[0],cam10_6_s2[1+12+16],lw=0.5)
#ax1.plot(cam10_6_s2[0],cam10_6_s2[1+13+16],lw=0.5)
#ax1.plot(cam10_6_s2[0],cam10_6_s2[1+15+16],lw=0.5)
ax1.plot(cam10_6_s2[0],cam10_6_s2[1+12+48],lw=0.5)
ax1.plot(cam10_6_s2[0],cam10_6_s2[1+13+48],lw=0.5)
ax1.plot(cam10_6_s2[0],cam10_6_s2[1+15+48],lw=0.5)
#ax1.set_ylim([0,1250])
#ax1.set_xlim([0,1500])

ax2=fig.add_subplot(122)
ax2.plot(cam5_6_s2[0],cam5_6_s2[1+12+16],lw=0.5)
#ax2.plot(cam5_6_s2[0],cam5_6_s2[1+13+16],lw=0.5)
#ax2.plot(cam5_6_s2[0],cam5_6_s2[1+15+16],lw=0.5)
ax2.plot(cam5_6_s2[0],cam5_6_s2[1+12+48],lw=0.5)
ax2.plot(cam5_6_s2[0],cam5_6_s2[1+13+48],lw=0.5)
ax2.plot(cam5_6_s2[0],cam5_6_s2[1+15+48],lw=0.5)
#ax2.set_ylim([0,1250])
#ax2.set_xlim([0,1500])
plt.show()

# %%
plt.plot(bK10_6_8ch[0],ac.camkii_count(bK10_6_8ch,'p'),'k')
plt.plot(cam10_6_8ch[0],ac.cam_count(cam10_6_8ch,'camKp')+cam10_6_8ch[49],'r')
plt.plot(bK10_6_8ch[0],ac.camkii_count(bK10_6_8ch,'p')-ac.camkii_count(bK10_6_8ch,'bp'),'b--')
plt.plot(bK10_6_8ch[0],ac.camkii_count(bK10_6_8ch,'n2'),'gold')

plt.plot(cam10_6_8ch[0],cam10_6_8ch[12+1+48]+cam10_6_8ch[13+1+48]+cam10_6_8ch[15+1+48],'aqua')
plt.plot(cam10_6_8ch[0],cam10_6_8ch[12+1+16]+cam10_6_8ch[13+1+16]+cam10_6_8ch[15+1+16],'lime')

plt.plot(bK5_6_8ch_scaled[0],ac.camkii_count(bK5_6_8ch_scaled,'p'),'k')
plt.plot(cam5_6_8ch_scaled[0],ac.cam_count(cam5_6_8ch_scaled,'camKp')+cam5_6_8ch_scaled[49],'r')
plt.plot(bK5_6_8ch_scaled[0],ac.camkii_count(bK5_6_8ch_scaled,'p')-ac.camkii_count(bK5_6_8ch_scaled,'bp'),'b--')
plt.plot(bK5_6_8ch_scaled[0],ac.camkii_count(bK5_6_8ch_scaled,'n2'),'gold')

plt.plot(cam5_6_8ch_scaled[0],cam5_6_8ch_scaled[12+1+48]+cam5_6_8ch_scaled[13+1+48]+cam5_6_8ch_scaled[15+1+48],'aqua')
plt.plot(cam5_6_8ch_scaled[0],cam5_6_8ch_scaled[12+1+16]+cam5_6_8ch_scaled[13+1+16]+cam5_6_8ch_scaled[15+1+16],'lime')

print "cam10_6_8ch: N0C2%=",np.sum(cam10_6_8ch[12+1+16],0)/np.sum(cam10_6_8ch[12+1+16]+cam10_6_8ch[13+1+16]+cam10_6_8ch[15+1+16],0)
print "cam10_6_8ch: N2C2%=",np.sum(cam10_6_8ch[15+1+16],0)/np.sum(cam10_6_8ch[12+1+16]+cam10_6_8ch[13+1+16]+cam10_6_8ch[15+1+16],0)
print "cam5_6_8ch_scaled: N0C2%=",np.sum(cam5_6_8ch_scaled[12+1+16],0)/np.sum(cam5_6_8ch_scaled[12+1+16]+cam5_6_8ch_scaled[13+1+16]+cam5_6_8ch_scaled[15+1+16],0)
print "cam5_6_8ch_scaled: N2C2%=",np.sum(cam5_6_8ch_scaled[15+1+16],0)/np.sum(cam5_6_8ch_scaled[12+1+16]+cam5_6_8ch_scaled[13+1+16]+cam5_6_8ch_scaled[15+1+16],0)

plt.show()
# Out:
# cam10_6_8ch: N0C2%= 0.843070568117
# cam10_6_8ch: N2C2%= 0.0748796791868
# cam5_6_8ch_scaled: N0C2%= 0.892777203192
# cam5_6_8ch_scaled: N2C2%= 0.0428868032293

# %%
# gold lines vs bKp lines: phosphorylation speed

plt.plot(bK10_6_s2[0],ac.camkii_count(bK10_6_s2,'p'),'k')
plt.plot(cam10_6_s2[0],ac.cam_count(cam10_6_s2,'camKp')+cam10_6_s2[49],'r')
plt.plot(bK10_6_s2[0],ac.camkii_count(bK10_6_s2,'p')-ac.camkii_count(bK10_6_s2,'bp'),'b--')
plt.plot(bK10_6_s2[0],ac.camkii_count(bK10_6_s2,'n2'),'gold')

#plt.plot(cam10_6_s2[0],ac.cam_count(cam10_6_s2,'camK')+cam10_6_s2[17],'brown')
# overlap with the brown line
#plt.plot(bK10_6_s2[0],ac.camkii_count(bK10_6_s2,'b')-ac.camkii_count(bK10_6_s2,'bp'),'g--',lw=2) 
plt.plot(cam10_6_s2[0],cam10_6_s2[12+1+48]+cam10_6_s2[13+1+48]+cam10_6_s2[15+1+48],'aqua')
plt.plot(cam10_6_s2[0],cam10_6_s2[12+1+16]+cam10_6_s2[13+1+16]+cam10_6_s2[15+1+16],'lime')

plt.plot(bK5_6_s2[0],ac.camkii_count(bK5_6_s2,'p'),'k')
plt.plot(cam5_6_s2[0],ac.cam_count(cam5_6_s2,'camKp')+cam5_6_s2[49],'r')
plt.plot(bK5_6_s2[0],ac.camkii_count(bK5_6_s2,'p')-ac.camkii_count(bK5_6_s2,'bp'),'b--')
plt.plot(bK5_6_s2[0],ac.camkii_count(bK5_6_s2,'n2'),'gold')

#plt.plot(cam5_6_s2[0],ac.cam_count(cam5_6_s2,'camK')+cam5_6_s2[17],'brown')
# overlap with the brown line
#plt.plot(bK5_6_s2[0],ac.camkii_count(bK5_6_s2,'b')-ac.camkii_count(bK5_6_s2,'bp'),'g--',lw=2) 
plt.plot(cam5_6_s2[0],cam5_6_s2[12+1+48]+cam5_6_s2[13+1+48]+cam5_6_s2[15+1+48],'aqua')
plt.plot(cam5_6_s2[0],cam5_6_s2[12+1+16]+cam5_6_s2[13+1+16]+cam5_6_s2[15+1+16],'lime')

print "cam10_6_s2: N0C2%=",np.sum(cam10_6_s2[12+1+16],0)/np.sum(cam10_6_s2[12+1+16]+cam10_6_s2[13+1+16]+cam10_6_s2[15+1+16],0)
print "cam10_6_s2: N2C2%=",np.sum(cam10_6_s2[15+1+16],0)/np.sum(cam10_6_s2[12+1+16]+cam10_6_s2[13+1+16]+cam10_6_s2[15+1+16],0)

print "cam5_6_s2: N0C2%=",np.sum(cam5_6_s2[12+1+16],0)/np.sum(cam5_6_s2[12+1+16]+cam5_6_s2[13+1+16]+cam5_6_s2[15+1+16],0)
print "cam5_6_s2: N2C2%=",np.sum(cam5_6_s2[15+1+16],0)/np.sum(cam5_6_s2[12+1+16]+cam5_6_s2[13+1+16]+cam5_6_s2[15+1+16],0)

plt.show()
# Out:
# cam10_6_s2: N0C2%= 0.532688909266
# cam10_6_s2: N2C2%= 0.327891696003
# cam5_6_s2: N0C2%= 0.624271201947
# cam5_6_s2: N2C2%= 0.233504230981
